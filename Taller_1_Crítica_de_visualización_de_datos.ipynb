# %% [markdown]
# <a href="https://colab.research.google.com/github/Natali1599/Visualizaci-n-de-datos-/blob/main/Taller_1_Cr%C3%ADtica_de_visualizaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Taller Nro1: Crítica de visualización de datos**

# %% [markdown]
# #####Estudiante: Natali Hernández Cardozo; Código: 2219950

# %% [markdown]
# **Visualización Nro 1: Covid CareMap.**

# %% [markdown]
# ######En esta visualización relacionada con fine de salud, se explica la capacidad de camas para pacientes que estén presentando COVID- 19, en todos los hospitales de EE.UU..

# %% [markdown]
# ![imagen1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **1.  Abstraer ¿qué?, ¿por qué? y ¿cómo?.**
#
# **¿Qué?**
#
# Table con items ordenados y representados por centro, condado, región de referencia del hospital o estado y atributos como:

# %% [markdown]
# ![imagen2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **¿por qué?**
#
# * Busca descubrir las diferencias de capacidad entre los hospitales que hay en EE.UU.
# * Presenta y produce anotaciones más específicas de los atributos.
# * Comparar las tendencias de capacidad de camas.
# * Analiza e identifica donde habría disponibilidad según el condado de llevar al paciente que presente anomalías de covid-19.
# * Localiza segíún los atributos de escala cual será su color.
#
# **¿cómo?**
#
# *  Encode ->  Map -> Navigate -> Select -> Superimpose -> Filter -> Aggregate
# * Color -> Saturation -> Motion
#
# **2.  Marcas y canales usados.**
#
# * Definiendo marcas y canales: Marcación por áreas. Canal de color por atributos de camas según capacidad.
#
# * Usando marcas y canales: Magnitud de los canales, lo realizan atrvés de saturación de colores. En una misma escala según los atributos a escoger. Y tienen un movimiento al ser escogido ese hospital en ese condado, muestra las características.
# * Eficacia de los canales: Por agrupación mediante colores de conexión, donde se tramite la información por medio de condado, y con los colores no se pierde el orden.
#
#
# **3.  Cumple o no cumple alguna de las reglas generales descritas.**
# Cumple la regla del mantra de la visualización, “Primero overview, zoom y filtro, detalles a petición”, ya que permite al espectador la experiencia de navegar y personalizar mediante filtros por distintos enfoques, ya sea por galguno de los atributos. Además, tiene la interactiva opción de que al dar clic sobre algun condado y ver sus características.
#
# **4. Mejoras posibles, en cuánto a marcas o canales, que le realizaría a la visualización.**
#
# No considero que la visualización debiera tener mejoras, debido a que tal cual como se encuentra proporciona gran información y de forma muy detalladas y personalizada para el espectador, que hace que sea posible la comprensión intuitiva e inmediata de lo expresado allí. Cambiando los items a estudiar obtenemos el dato que querramos.

# %% [markdown]
# *Fuente: https://www.covidcaremap.org/maps/us-healthcare-system-capacity/#5.25/34.068/-99.191*

# %% [markdown]
# **Visualización Nro 2:**

# %% [markdown]
# ######En esta visualización se verán las filtaciones de datos y hackeos que han habido a lo largo de los años y que se caracterizan por ser los más grandes del mundo.

# %% [markdown]
# ![imagen3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **1. Abstraer ¿qué?, ¿por qué? y ¿cómo?.**
#
# **¿Qué?**
#
# Table con items de año a año y representados por atributos como son las aplicaciones, programas, desarrolladores, entre otros. Con dinamica al seleccionar el acontecimiento llevarnos a una descripción o noticia de lo sucedido.
# Los atributos están de manera ordenado, es decir, el tamaño de los circulos, van según su importancia. Y los anaranjados, que han sido historias interesantes.
#
# **¿por qué?**
#
# Present, Enjoy, Look up , explore, correlation y trend.
#
# * PReesenta los gran hechos de hacker's en los años.
# * Produce anotaciónes de casos que se desconocen y son interesantes para recordar.
# *  Se disfruta y se explora de información con las noticias en otras páginas adicionales.
# * Correlación de los hechos con cuestión de tiempo e importancia.
# * Tendencias de lo que está siendo un caos irrepetible.
#
# **¿cómo?**
#
# *  Encode ->  Order -> Map -> Shape -> Size
# * Encode -> Select -> Superimpose -> Filter -> Aggregate
#
# **2.  Marcas y canales usados.**
#
# * Definiendo marcas y canales: Marcación por puntos. Canal de color para el atributo de aplicación, desarrollador, programa, etc. También, canal de tamaño para el atributo de impacto personas damnificadas.
#
# * Usando marcas y canales: Por magnitud, la posición en escala, tamaño. Por identificación de canales: La región espacial, el movimiento y las forma en circulos.
#
# * Eficacia de los canales: La separabilidad con las interacciones y combinaciones que le dan una mejor interferencia. Popout, la forma, el tamaño. Agrupación, por proximidad de los años en que suceden los hechos.
# Para el caso de los ejes del gráfico se pueden realizar filtros según carcterísticas se quieran evaluar.
#
#
# **3.  Cumple o no cumple alguna de las reglas generales descritas.**
# 2D injustificado, muestran la cantidad máxima de información en un espacio mínimo.
# Memoria y atención; la pantalla cambia para mostrar la escenda desde otra página por ende se logrará más atención y comodidad par recibir la información.
# Además también cumple la regla del mantra de la visualización, “Primero overview, zoom y filtro, detalles a petición”, ya que permite al espectador la experiencia de navegar y personalizar mediante filtros por distintos enfoques, ya sea por galguno de los atributos. Además, tiene la interactiva opción de que al dar clic sobre algun círculo y ver que sucedió.
#
# **4. Mejoras posibles, en cuánto a marcas o canales, que le realizaría a la visualización.**
#
# Considero que aunque uno de los acontecimientos no logré gran impacto o caos en los medios deberían de darse a conocer con algo que se llame "otros". De resto considero que la información y sus diseños están demasiado adecuados.

# %% [markdown]
# *Fuente:https://informationisbeautiful.net/visualizations/worlds-biggest-data-breaches-hacks/*
